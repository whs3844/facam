# %% [markdown]
# ### numpy를 사용하는 이유
# - 성능 : 파이썬 리스트보다 빠름
# - 메모리 사이즈 ; 파이썬 리스트보다 적은 메모리 사용
# - 빌트인 함수 : 선형대수, 통계관련 여러 함수 내장

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3])
y = np.array([2,4,6])

plt.plot(x,y)
